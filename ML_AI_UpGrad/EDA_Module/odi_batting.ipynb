# %%
#Import all the necessary libraries here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
#loading data
df=pd.read_csv("odi-batting.csv")
df
# Out:
#            Country               Player  Runs   MatchDate Weekday  \
# 0      Afghanistan     Mohammad Shahzad   118  16-02-2010     Tue
# 1      Afghanistan     Mohammad Shahzad   110  01-09-2009     Tue
# 2      Afghanistan     Mohammad Shahzad   100  16-08-2010     Mon
# 3      Afghanistan     Mohammad Shahzad    82  10-07-2010     Sat
# 4      Afghanistan     Mohammad Shahzad    57  01-07-2010     Thu
# ...            ...                  ...   ...         ...     ...
# 50279     Zimbabwe        Kevin G Duers     5  10-03-1992     Tue
# 50280     Zimbabwe        Kevin G Duers     2  14-03-1992     Sat
# 50281     Zimbabwe        Ujesh Ranchod     3  03-02-1993     Wed
# 50282     Zimbabwe       Brian V Vitori     3  14-09-2011     Wed
# 50283     Zimbabwe  Waddington Mwayenga     1  29-05-2004     Sat
#
#                       Ground        Versus  Balls
# 0         Sharjah CA Stadium        Canada    121
# 1                 VRA Ground   Netherlands    111
# ...

# %%
new_df = df[df['Runs'] >=100]
new_df
# Out:
#            Country               Player  Runs   MatchDate Weekday  \
# 0      Afghanistan     Mohammad Shahzad   118  16-02-2010     Tue
# 1      Afghanistan     Mohammad Shahzad   110  01-09-2009     Tue
# 2      Afghanistan     Mohammad Shahzad   100  16-08-2010     Mon
# 62     Afghanistan      Noor Ali Zadran   114  16-02-2010     Tue
# 87     Afghanistan         Karim Sadiq    114  16-08-2010     Mon
# ...            ...                  ...   ...         ...     ...
# 48682     Zimbabwe     David L Houghton   142  10-10-1987     Sat
# 48737     Zimbabwe       Dion D Ebrahim   121  25-11-2001     Sun
# 49101     Zimbabwe   Charles K Coventry   194  16-08-2009     Sun
# 49208     Zimbabwe        Sean M Ervine   100  24-01-2004     Sat
# 49237     Zimbabwe  Douglas A Marillier   100  05-04-2003     Sat
#
#                              Ground       Versus  Balls
# 0                Sharjah CA Stadium       Canada    121
# 1                        VRA Ground  Netherlands    111
# ...

# %%
new_df['strike_rate'] = df['Runs']/df['Balls'] *100
new_df
# Out:
# /var/folders/km/pkl5v8zn3lxfq4cg_k3j4b0r0000gn/T/ipykernel_66531/373147299.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['strike_rate'] = df['Runs']/df['Balls'] *100
#            Country               Player  Runs   MatchDate Weekday  \
# 0      Afghanistan     Mohammad Shahzad   118  16-02-2010     Tue
# 1      Afghanistan     Mohammad Shahzad   110  01-09-2009     Tue
# 2      Afghanistan     Mohammad Shahzad   100  16-08-2010     Mon
# 62     Afghanistan      Noor Ali Zadran   114  16-02-2010     Tue
# 87     Afghanistan         Karim Sadiq    114  16-08-2010     Mon
# ...            ...                  ...   ...         ...     ...
# 48682     Zimbabwe     David L Houghton   142  10-10-1987     Sat
# ...

# %%
new_df['strike_rate'].max()
# Out:
# 254.99999999999997

# %%
new_df[new_df['strike_rate']==254.99999999999997]['Player'].item()
# Out:
# 'Shahid Afridi'

# %%
indian_players = df[df['Country'] == 'India']
indian_players
# Out:
#       Country              Player  Runs   MatchDate Weekday  \
# 13601   India  Sachin R Tendulkar   200  24-02-2010     Wed
# 13602   India  Sachin R Tendulkar   186  08-11-1999     Mon
# 13603   India  Sachin R Tendulkar   175  05-11-2009     Thu
# 13604   India  Sachin R Tendulkar   163  08-03-2009     Sun
# 13605   India  Sachin R Tendulkar   152  23-02-2003     Sun
# ...       ...                 ...   ...         ...     ...
# 19645   India     Rajinder S Ghai     1  26-01-1986     Sun
# 19646   India     Nandlal S Yadav     1  09-02-1986     Sun
# 19647   India        Naman V Ojha     1  05-06-2010     Sat
# 19648   India        Sudeep Tyagi     1  27-02-2010     Sat
# 19649   India        Yograj Singh     1  14-02-1981     Sat
#
#                                    Ground        Versus  Balls
# 13601          Captain Roop Singh Stadium  South Africa    147
# 13602         Lal Bahadur Shastri Stadium   New Zealand    150
# ...

# %%
indian_players['Year'] = pd.to_datetime(indian_players['MatchDate'], format='%d-%m-%Y').dt.year
indian_players
# Out:
# /var/folders/km/pkl5v8zn3lxfq4cg_k3j4b0r0000gn/T/ipykernel_66531/2778333904.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   indian_players['Year'] = pd.to_datetime(indian_players['MatchDate'], format='%d-%m-%Y').dt.year
#       Country              Player  Runs   MatchDate Weekday  \
# 13601   India  Sachin R Tendulkar   200  24-02-2010     Wed
# 13602   India  Sachin R Tendulkar   186  08-11-1999     Mon
# 13603   India  Sachin R Tendulkar   175  05-11-2009     Thu
# 13604   India  Sachin R Tendulkar   163  08-03-2009     Sun
# 13605   India  Sachin R Tendulkar   152  23-02-2003     Sun
# ...       ...                 ...   ...         ...     ...
# 19645   India     Rajinder S Ghai     1  26-01-1986     Sun
# ...
