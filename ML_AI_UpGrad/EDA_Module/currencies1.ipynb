# %%
#Import all the necessary libraries here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
#loading data
df=pd.read_csv("currencies.csv")
df
# Out:
#          Currency  Chinese Yuan     Euro  Japanese Yen  U.K. Pound Sterling  \
# 0   July 01, 2016       9.29446  1.25367       143.645              1.05054
# 1   July 05, 2016       9.31515  1.25322       142.715              1.06143
# 2   July 06, 2016       9.31697  1.25834       140.540              1.07300
# 3   July 07, 2016       9.31315  1.25737       140.640              1.06911
# 4   July 08, 2016       9.31350  1.25797       140.510              1.07261
# 5   July 11, 2016       9.29403  1.25769       139.962              1.07050
# 6   July 12, 2016       9.31021  1.25490       143.369              1.05762
# 7   July 13, 2016       9.31350  1.25716       145.178              1.04680
# 8   July 14, 2016       9.30432  1.24695       144.895              1.05236
# 9   July 15, 2016       9.31532  1.25263       147.268              1.04242
# 10  July 18, 2016       9.30354  1.25652           NaN              1.04952
#
# ...

# %%
df.columns
# Out:
# Index(['Currency', 'Chinese Yuan', 'Euro', 'Japanese Yen',
#        'U.K. Pound Sterling', 'U.S. Dollar', 'Algerian Dinar',
#        'Australian Dollar', 'Bahrain Dinar', 'Botswana Pula', 'Brazilian Real',
#        'Brunei Dollar', 'Canadian Dollar', 'Chilean Peso', 'Colombian Peso',
#        'Czech Koruna', 'Danish Krone', 'Hungarian Forint', 'Icelandic Krona',
#        'Indian Rupee', 'Indonesian Rupiah', 'Iranian Rial',
#        'Israeli New Sheqel', 'Kazakhstani Tenge', 'Korean Won',
#        'Kuwaiti Dinar', 'Libyan Dinar', 'Malaysian Ringgit', 'Mauritian Rupee',
#        'Mexican Peso', 'Nepalese Rupee', 'New Zealand Dollar',
#        'Norwegian Krone', 'Rial Omani', 'Pakistani Rupee', 'Nuevo Sol',
#        'Philippine Peso', 'Polish Zloty', 'Qatar Riyal', 'Russian Ruble',
#        'Saudi Arabian Riyal', 'Singapore Dollar', 'South African Rand',
#        'Sri Lanka Rupee', 'Swedish Krona', 'Swiss Franc', 'Thai Baht',
# ...

# %%
#Euro, Japanese Yen, U.K. Pound Sterling, US Dollar, Chineese Yuan, Australian Dollar, Indian Rupee.
df1 = df[['Euro','Japanese Yen','U.K. Pound Sterling','U.S. Dollar','Chinese Yuan','Australian Dollar','Indian Rupee']]
df1
# Out:
#        Euro  Japanese Yen  U.K. Pound Sterling  U.S. Dollar  Chinese Yuan  \
# 0   1.25367       143.645              1.05054      1.39596       9.29446
# 1   1.25322       142.715              1.06143      1.39684       9.31515
# 2   1.25834       140.540              1.07300      1.39286       9.31697
# 3   1.25737       140.640              1.06911      1.39316       9.31315
# 4   1.25797       140.510              1.07261      1.39257       9.31350
# 5   1.25769       139.962              1.07050      1.38962       9.29403
# 6   1.25490       143.369              1.05762      1.39194       9.31021
# 7   1.25716       145.178              1.04680      1.39193       9.31350
# 8   1.24695       144.895              1.05236      1.39122       9.30432
# 9   1.25263       147.268              1.04242      1.39392       9.31532
# 10  1.25652           NaN              1.04952      1.38883       9.30354
#
#     Australian Dollar  Indian Rupee
# 0             1.87126       94.1451
# ...

# %%
corr = df1.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_61302_row0_col0, #T_61302_row1_col1, #T_61302_row2_col2, #T_61302_row3_col3, #T_61302_row4_col4, #T_61302_row5_col5, #T_61302_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_61302_row0_col1 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_61302_row0_col2 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_61302_row0_col3, #T_61302_row1_col0, #T_61302_row1_col2, #T_61302_row1_col5, #T_61302_row1_col6, #T_61302_row2_col1, #T_61302_row5_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_61302_row0_col4 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_61302_row0_col5 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_61302_row0_col6 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_61302_row1_col3 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_61302_row1_col4 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_61302_row2_col0 {
# ...
